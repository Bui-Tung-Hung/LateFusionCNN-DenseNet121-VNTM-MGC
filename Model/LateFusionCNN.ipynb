# %%
import cv2
import numpy as np
import os
import librosa 


import keras
from keras.applications import DenseNet121
from keras.models import Model, Sequential
from keras import layers



import tensorflow as tf
import tensorflow.keras.layers
from tensorflow.keras.preprocessing import image

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Input, Concatenate, Dense
from tensorflow.keras.models import Model


from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, LabelBinarizer



from PIL import Image

# %%
def compute_melgram(audio_path, new_shape=(256, 1296)):


    # Mel-spectrogram parameters
    SR = 12000
    N_FFT = 2048
    N_MELS = 256
    HOP_LEN = 256
    DURA = 27.64  # to make it 1296 frames

    # Load audio file
    src, sr = librosa.load(audio_path, sr=SR)

    # Ensure the audio is of desired duration
    n_sample = src.shape[0]
    n_sample_fit = int(DURA * SR)
    if n_sample < n_sample_fit:  # if too short
        src = np.hstack((src, np.zeros((int(DURA * SR) - n_sample,))))
    elif n_sample > n_sample_fit:  # if too long
        src = src[(n_sample - n_sample_fit) // 2:(n_sample + n_sample_fit) // 2]
    melgram = librosa.feature.melspectrogram(y=src, sr=SR, hop_length=HOP_LEN, n_fft=N_FFT, n_mels=N_MELS)

    return melgram
def compute_stft(audio_path,new_shape=(256, 1296)):


    # STFT parameters
    SR = 22115
    N_FFT = 510
    HOP_LEN = 512

    # Load audio file
    src, sr = librosa.load(audio_path, sr=SR)

    # Compute STFT
    stft = librosa.stft(src, n_fft=N_FFT, hop_length=HOP_LEN)

    return stft

def compute_mfcc(audio_path,new_shape=(256, 1296)):


    # MFCC parameters
    SR = 22115
    N_MFCC = 256
    N_FFT = 510
    HOP_LEN = 512

    # Load audio file
    src, sr = librosa.load(audio_path, sr=SR)

    # Compute MFCC
    mfcc = librosa.feature.mfcc(y=src, sr=SR, n_mfcc=N_MFCC, n_fft=N_FFT, hop_length=HOP_LEN)
    return mfcc


def process_audio_files(audio_dir):
    stft_data = []
    mel_data = []
    mfcc_data = []
    labels = []

    max_frames = 1296  # Set a maximum number of frames
    n_freq_bins = 256  # Number of frequency bins in the Mel-spectrogram

    for genre_folder in os.listdir(audio_dir):
        genre_path = os.path.join(audio_dir, genre_folder)
        if os.path.isdir(genre_path):
            for filename in os.listdir(genre_path):
                if filename.endswith('.wav'):
                    file_path = os.path.join(genre_path, filename)
                    stft = compute_stft(file_path)
                    mel = compute_melgram(file_path)
                    mfcc = compute_mfcc(file_path)
                    
                    # Upsample MFCCs
                    mfcc_upsampled = upsample_mfcc(mfcc, n_freq_bins)
                    
                    # Pad or crop arrays to ensure consistent shape
                    stft = pad_or_crop_array(stft, max_frames)
                    mel = pad_or_crop_array(mel, max_frames)
                    mfcc_upsampled = pad_or_crop_array(mfcc_upsampled, max_frames)
                    
                    stft_data.append(stft)
                    mel_data.append(mel)
                    mfcc_data.append(mfcc_upsampled)
                    labels.append(genre_folder)

    stft_data = np.array(stft_data)
    mel_data = np.array(mel_data)
    mfcc_data = np.array(mfcc_data)
    labels = np.array(labels)

    return stft_data, mel_data, mfcc_data, labels

# Function to upsample MFCCs
def upsample_mfcc(mfcc_data, n_freq_bins):
    n_mfcc, n_frames = mfcc_data.shape
    mfcc_upsampled = np.zeros((n_freq_bins, n_frames))

    # Compute interpolation factor for each MFCC coefficient
    factor = n_freq_bins // n_mfcc

    # Upsample each MFCC coefficient
    for i in range(n_mfcc):
        mfcc_upsampled[i*factor:(i+1)*factor, :] = mfcc_data[i]

    return mfcc_upsampled


def pad_or_crop_array(array, target_length):
    if array.shape[1] < target_length:
        # Pad array with zeros along the time axis
        padding = target_length - array.shape[1]
        array = np.pad(array, ((0, 0), (0, padding)), mode='constant')
    elif array.shape[1] > target_length:
        # Crop array along the time axis
        array = array[:, :target_length]
    return array

audio_dir = 'D:\ProjectMusicGenre\data\VNTM3'
stft_data, mel_data, mfcc_data, labels = process_audio_files(audio_dir)

# %%
# Here you can continue with your splitting and reshaping steps as before
stft_data = stft_data.reshape(stft_data.shape[0], stft_data.shape[1], stft_data.shape[2], 1)
mel_data = mel_data.reshape(mel_data.shape[0], mel_data.shape[1], mel_data.shape[2], 1)
mfcc_data = mfcc_data.reshape(mfcc_data.shape[0], mfcc_data.shape[1], mfcc_data.shape[2], 1)

# %%
stft_data=stft_data.astype("float32")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10940\1535179258.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   stft_data=stft_data.astype("float32")

# %%
mel_data =  mel_data.astype("float32")

# %%
mfcc_data =mfcc_data.astype("float32")

# %%
# Split the data into training and testing sets (80% train, 20% test)
stft_train, stft_test, mel_train, mel_test, mfcc_train, mfcc_test, labels_train, labels_test = train_test_split(
    stft_data, mel_data, mfcc_data, labels, test_size=0.2, random_state=42)

# Split the training data into training and validation sets (80% train, 20% validation)
stft_test, stft_val, mel_test, mel_val, mfcc_test, mfcc_val, labels_test, labels_val = train_test_split(
    stft_test, mel_test, mfcc_test, labels_test, test_size=0.5, random_state=42)

# %%
checkpoint_filepath = r'D:\ProjectMusicGenre\data\checkpoint'
dataset_root =r'D:\ProjectMusicGenre\data'
saved_model_path = r'D:\ProjectMusicGenre\data\model'

# %%
from tensorflow.keras.layers import Dropout, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization

def late_fusion(model,stft_input_shape, melgram_input_shape,mfcc_input_shape):
    # Define Group1 Block
    input_stft = Input(shape=stft_input_shape)
    stft = Conv2D(20, (7, 7), strides=(2, 2), activation='relu', padding='same')(input_stft)
    stft = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(stft)
    stft = dropout_block(stft, units=42)
    stft = transition_layer(stft, filters=42)
    stft = dropout_block(stft, units=85)
    stft = transition_layer(stft, filters=85)
    stft = dropout_block(stft, units=170)
    stft = transition_layer(stft, filters=170)
    stft = dropout_block(stft, units=341)
    stft = GlobalAveragePooling2D()(stft)  # Adding Global Average Pooling


    # Define Group2 Block
    input_melgram = Input(shape=melgram_input_shape)
    melgram = Conv2D(20, (7, 7), strides=(2, 2), activation='relu', padding='same')(input_melgram)
    melgram = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(melgram)
    melgram = dropout_block(melgram, units=42)
    melgram = transition_layer(melgram, filters=42)
    melgram = dropout_block(melgram, units=85)
    melgram = transition_layer(melgram, filters=85)
    melgram = dropout_block(melgram, units=170)
    melgram = transition_layer(melgram, filters=170)
    melgram = dropout_block(melgram, units=341)
    melgram = GlobalAveragePooling2D()(melgram)
    # Define Group3 Block


    input_mfcc = Input(shape=mfcc_input_shape)
    mfcc = Conv2D(20, (7, 7), strides=(2, 2), activation='relu', padding='same')(input_mfcc)
    mfcc = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(mfcc)
    mfcc = dropout_block(mfcc, units=42)  # Using a function for dropout block
    mfcc = transition_layer(mfcc, filters=42)
    mfcc = dropout_block(mfcc, units=85)
    mfcc = transition_layer(mfcc, filters=85)
    mfcc = dropout_block(mfcc, units=170)
    mfcc = transition_layer(mfcc, filters=170)
    mfcc = dropout_block(mfcc, units=341)
    mfcc = GlobalAveragePooling2D()(mfcc)  # Adding Global Average Pooling

    # Concatenate outputs of all groups
    concatenated_output = Concatenate()([ stft, melgram,mfcc])

    # Global Average Pooling
    # Fully Connected Layer
    output = Dense(5, activation='softmax')(concatenated_output)

    # Define the model
    model = Model(inputs=[ input_stft, input_melgram,input_mfcc], outputs=output)
    if not os.path.exists(checkpoint_filepath + '/latefusion'):
        os.makedirs(checkpoint_filepath + '/latefusion')
    checkpoint1= tf.keras.callbacks.ModelCheckpoint(
    filepath= checkpoint_filepath + '/latefusion' + '/latefusion_{epoch:02d}_{val_accuracy:.4f}.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
    )

    return model,checkpoint1

def dropout_block(input_layer, units):
    x = Dense(units, activation='relu')(input_layer)
    x = Dropout(0.1)(x)
    return x

def transition_layer(input_layer, filters):
    x = Conv2D(filters, (1, 1), activation='relu')(input_layer)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    return x

# %%
from tensorflow.keras.optimizers import Adam

# Instantiate the late fusion model using provided input shapes
mfcc_input_shape = (256, 1296, 1)  # Example shape, adjust according to your actual data
stft_input_shape = (256, 1296, 1)  # Example shape, adjust according to your actual data
melgram_input_shape = (256, 1296, 1)  # Example shape, adjust according to your actual data
model1 = tf.keras.Sequential()
model1,checkpoint1 = late_fusion(model1,stft_input_shape ,melgram_input_shape, mfcc_input_shape,)

# Compile the model
model1.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 1296, │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 256, 1296, │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 256, 1296, │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 648,  │      1,000 │ input_layer[0][0] │
# │                     │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 648,  │      1,000 │ input_layer_1[0]… │
# │                     │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 648,  │      1,000 │ input_layer_2[0]… │
# │                     │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 63, 323,   │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 63, 323,   │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 63, 323,   │          0 │ conv2d_8[0][0]    │
# │ (MaxPooling2D)      │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 63, 323,   │        882 │ max_pooling2d[0]… │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 63, 323,   │        882 │ max_pooling2d_4[… │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 63, 323,   │        882 │ max_pooling2d_8[… │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 63, 323,   │          0 │ dense[0][0]       │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 63, 323,   │          0 │ dense_4[0][0]     │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 63, 323,   │          0 │ dense_8[0][0]     │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 63, 323,   │      1,806 │ dropout[0][0]     │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 63, 323,   │      1,806 │ dropout_4[0][0]   │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 63, 323,   │      1,806 │ dropout_8[0][0]   │
# │                     │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 31, 161,   │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 31, 161,   │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 31, 161,   │          0 │ conv2d_9[0][0]    │
# │ (MaxPooling2D)      │ 42)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 31, 161,   │      3,655 │ max_pooling2d_1[… │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 31, 161,   │      3,655 │ max_pooling2d_5[… │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 31, 161,   │      3,655 │ max_pooling2d_9[… │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 31, 161,   │          0 │ dense_1[0][0]     │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 31, 161,   │          0 │ dense_5[0][0]     │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 31, 161,   │          0 │ dense_9[0][0]     │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 31, 161,   │      7,310 │ dropout_1[0][0]   │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 31, 161,   │      7,310 │ dropout_5[0][0]   │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 31, 161,   │      7,310 │ dropout_9[0][0]   │
# │                     │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 15, 80,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 15, 80,    │          0 │ conv2d_6[0][0]    │
# │ (MaxPooling2D)      │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 15, 80,    │          0 │ conv2d_10[0][0]   │
# │ (MaxPooling2D)      │ 85)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 15, 80,    │     14,620 │ max_pooling2d_2[… │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 15, 80,    │     14,620 │ max_pooling2d_6[… │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 15, 80,    │     14,620 │ max_pooling2d_10… │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 15, 80,    │          0 │ dense_2[0][0]     │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 15, 80,    │          0 │ dense_6[0][0]     │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 15, 80,    │          0 │ dense_10[0][0]    │
# │ (Dropout)           │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 15, 80,    │     29,070 │ dropout_2[0][0]   │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 15, 80,    │     29,070 │ dropout_6[0][0]   │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 15, 80,    │     29,070 │ dropout_10[0][0]  │
# │                     │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 7, 40,     │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 7, 40,     │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 7, 40,     │          0 │ conv2d_11[0][0]   │
# │ (MaxPooling2D)      │ 170)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 7, 40,     │     58,311 │ max_pooling2d_3[… │
# │                     │ 341)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 7, 40,     │     58,311 │ max_pooling2d_7[… │
# │                     │ 341)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 7, 40,     │     58,311 │ max_pooling2d_11… │
# │                     │ 341)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 7, 40,     │          0 │ dense_3[0][0]     │
# │                     │ 341)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 7, 40,     │          0 │ dense_7[0][0]     │
# │                     │ 341)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 7, 40,     │          0 │ dense_11[0][0]    │
# │ (Dropout)           │ 341)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 341)       │          0 │ dropout_3[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 341)       │          0 │ dropout_7[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 341)       │          0 │ dropout_11[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 1023)      │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# │                     │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 5)         │      5,120 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 355,082 (1.35 MB)
#  Trainable params: 355,082 (1.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import EarlyStopping

early = EarlyStopping(monitor='loss',
    patience= 5,
    verbose= 0,
    mode='auto',
    baseline= None,
    restore_best_weights= True)

# %%
from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer()
y_train_one_hot = label_binarizer.fit_transform(labels_train)
y_val_one_hot = label_binarizer.transform(labels_val)
y_eval_one_hot = label_binarizer.transform(labels_test)

# %%
history = model1.fit([stft_train,  mel_train,mfcc_train], y_train_one_hot, batch_size=32, epochs=100, validation_data=([stft_val,mel_val,mfcc_val], y_val_one_hot),callbacks=[checkpoint1, early])
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2865 - loss: 1.9246
# Epoch 1: val_accuracy improved from -inf to 0.56800, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_01_0.5680.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.2880 - loss: 1.9176 - val_accuracy: 0.5680 - val_loss: 1.0915
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6089 - loss: 0.9938
# Epoch 2: val_accuracy improved from 0.56800 to 0.66000, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_02_0.6600.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.6090 - loss: 0.9933 - val_accuracy: 0.6600 - val_loss: 0.9777
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6743 - loss: 0.8561
# Epoch 3: val_accuracy improved from 0.66000 to 0.69600, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_03_0.6960.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.6748 - loss: 0.8550 - val_accuracy: 0.6960 - val_loss: 0.7672
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7425 - loss: 0.6901
# Epoch 4: val_accuracy improved from 0.69600 to 0.77200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_04_0.7720.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.7428 - loss: 0.6894 - val_accuracy: 0.7720 - val_loss: 0.6405
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7842 - loss: 0.6161
# Epoch 5: val_accuracy improved from 0.77200 to 0.78800, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_05_0.7880.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.7845 - loss: 0.6152 - val_accuracy: 0.7880 - val_loss: 0.5796
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8305 - loss: 0.4810
# Epoch 6: val_accuracy did not improve from 0.78800
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8306 - loss: 0.4806 - val_accuracy: 0.7840 - val_loss: 0.5167
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8769 - loss: 0.3396
# Epoch 7: val_accuracy improved from 0.78800 to 0.85200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_07_0.8520.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8767 - loss: 0.3402 - val_accuracy: 0.8520 - val_loss: 0.5032
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8856 - loss: 0.3314
# Epoch 8: val_accuracy did not improve from 0.85200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8857 - loss: 0.3311 - val_accuracy: 0.8480 - val_loss: 0.3633
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9068 - loss: 0.2617
# Epoch 9: val_accuracy improved from 0.85200 to 0.87200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_09_0.8720.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9067 - loss: 0.2621 - val_accuracy: 0.8720 - val_loss: 0.2978
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9103 - loss: 0.2652
# Epoch 10: val_accuracy did not improve from 0.87200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9103 - loss: 0.2651 - val_accuracy: 0.7960 - val_loss: 0.5023
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9025 - loss: 0.2666
# Epoch 11: val_accuracy improved from 0.87200 to 0.94000, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_11_0.9400.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9028 - loss: 0.2658 - val_accuracy: 0.9400 - val_loss: 0.1922
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9335 - loss: 0.2031
# Epoch 12: val_accuracy did not improve from 0.94000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9333 - loss: 0.2035 - val_accuracy: 0.9120 - val_loss: 0.2463
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9565 - loss: 0.1167 - val_accuracy: 0.9440 - val_loss: 0.1522
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9533 - loss: 0.1141
# Epoch 32: val_accuracy did not improve from 0.96800
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9534 - loss: 0.1139 - val_accuracy: 0.9680 - val_loss: 0.0994
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9743 - loss: 0.0820
# Epoch 33: val_accuracy did not improve from 0.96800
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9743 - loss: 0.0819 - val_accuracy: 0.9560 - val_loss: 0.1328
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9475 - loss: 0.1462
# Epoch 34: val_accuracy did not improve from 0.96800
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9477 - loss: 0.1460 - val_accuracy: 0.9480 - val_loss: 0.1516

# %%
from sklearn.metrics import accuracy_score
from keras.metrics import AUC, F1Score, Precision, Accuracy

# Evaluate the model
predict = model1.predict([stft_test,mel_test,mfcc_test])
predicted_labels = label_binarizer.inverse_transform(predict).tolist()

# loss_eval, accuracy_eval = model.evaluate(X_eval, y_eval_one_hot)

# print(f'Evaluation Loss: {loss_eval}, Evaluation Accuracy: {accuracy_eval}')
# Calculate AUC ROC
auc_roc = AUC()
auc_roc.update_state(y_eval_one_hot, predict)
print("AUC ROC:", auc_roc.result().numpy())

# Calculate F1 Score
f1 = F1Score()
f1.update_state(y_eval_one_hot, predict)
print("F1 Score:", np.mean(f1.result().numpy()))

# Calculate Precision
pre = Precision()
pre.update_state(y_eval_one_hot, predict)
print("Precision Score", pre.result().numpy())

# Accuracy Score
acc = accuracy_score(labels_test, predicted_labels)
print("Accuracy Score", acc)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step
# AUC ROC: 0.9972679
# F1 Score: 0.9404189
# Precision Score 0.94779116
# Accuracy Score 0.944

# %%
history = model1.fit([stft_train,  mel_train,mfcc_train], y_train_one_hot, batch_size=32, epochs=100, validation_data=([stft_val,mel_val,mfcc_val], y_val_one_hot),callbacks=[checkpoint1, early])
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3767 - loss: 1.5690
# Epoch 1: val_accuracy improved from -inf to 0.58000, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_01_0.5800.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.3782 - loss: 1.5644 - val_accuracy: 0.5800 - val_loss: 0.9361
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6734 - loss: 0.8545
# Epoch 2: val_accuracy improved from 0.58000 to 0.74000, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_02_0.7400.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.6737 - loss: 0.8540 - val_accuracy: 0.7400 - val_loss: 0.7989
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7155 - loss: 0.7648
# Epoch 3: val_accuracy improved from 0.74000 to 0.80400, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_03_0.8040.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.7157 - loss: 0.7643 - val_accuracy: 0.8040 - val_loss: 0.5806
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7780 - loss: 0.5866
# Epoch 4: val_accuracy did not improve from 0.80400
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.7780 - loss: 0.5870 - val_accuracy: 0.6680 - val_loss: 0.7953
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7540 - loss: 0.6046
# Epoch 5: val_accuracy improved from 0.80400 to 0.82400, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_05_0.8240.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.7545 - loss: 0.6041 - val_accuracy: 0.8240 - val_loss: 0.4932
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8670 - loss: 0.4063
# Epoch 6: val_accuracy did not improve from 0.82400
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8669 - loss: 0.4064 - val_accuracy: 0.7840 - val_loss: 0.5623
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8083 - loss: 0.5309
# Epoch 7: val_accuracy improved from 0.82400 to 0.83600, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_07_0.8360.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8088 - loss: 0.5298 - val_accuracy: 0.8360 - val_loss: 0.4649
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8729 - loss: 0.3572
# Epoch 8: val_accuracy improved from 0.83600 to 0.88400, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_08_0.8840.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8728 - loss: 0.3574 - val_accuracy: 0.8840 - val_loss: 0.3500
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9020 - loss: 0.3103
# Epoch 9: val_accuracy did not improve from 0.88400
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9018 - loss: 0.3106 - val_accuracy: 0.8600 - val_loss: 0.3978
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8846 - loss: 0.3208
# Epoch 10: val_accuracy did not improve from 0.88400
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8846 - loss: 0.3207 - val_accuracy: 0.8000 - val_loss: 0.4833
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8794 - loss: 0.3712
# Epoch 11: val_accuracy did not improve from 0.88400
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8795 - loss: 0.3708 - val_accuracy: 0.8640 - val_loss: 0.3533
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9147 - loss: 0.2289
# Epoch 12: val_accuracy did not improve from 0.88400
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.9144 - loss: 0.2297 - val_accuracy: 0.7280 - val_loss: 0.7778
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8603 - loss: 0.4032
# Epoch 13: val_accuracy improved from 0.88400 to 0.91200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_13_0.9120.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8608 - loss: 0.4016 - val_accuracy: 0.9120 - val_loss: 0.2580
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9368 - loss: 0.1739
# Epoch 14: val_accuracy did not improve from 0.91200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.9367 - loss: 0.1742 - val_accuracy: 0.8280 - val_loss: 0.4410
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9178 - loss: 0.2164
# Epoch 15: val_accuracy did not improve from 0.91200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9181 - loss: 0.2159 - val_accuracy: 0.9040 - val_loss: 0.2846
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9195 - loss: 0.2411
# Epoch 16: val_accuracy improved from 0.91200 to 0.93200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_16_0.9320.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9197 - loss: 0.2406 - val_accuracy: 0.9320 - val_loss: 0.1883
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9579 - loss: 0.1435
# Epoch 17: val_accuracy did not improve from 0.93200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9579 - loss: 0.1435 - val_accuracy: 0.9120 - val_loss: 0.2486
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9123 - loss: 0.2429
# Epoch 18: val_accuracy did not improve from 0.93200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9123 - loss: 0.2428 - val_accuracy: 0.8640 - val_loss: 0.3765
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9446 - loss: 0.1562
# Epoch 19: val_accuracy improved from 0.93200 to 0.95200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_19_0.9520.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9446 - loss: 0.1561 - val_accuracy: 0.9520 - val_loss: 0.1934
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9450 - loss: 0.1645
# Epoch 20: val_accuracy did not improve from 0.95200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9451 - loss: 0.1642 - val_accuracy: 0.9160 - val_loss: 0.2139
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9131 - loss: 0.2218
# Epoch 21: val_accuracy did not improve from 0.95200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9133 - loss: 0.2212 - val_accuracy: 0.8560 - val_loss: 0.3763
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9194 - loss: 0.2186
# Epoch 22: val_accuracy did not improve from 0.95200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.9196 - loss: 0.2180 - val_accuracy: 0.9280 - val_loss: 0.2147

# %%
from sklearn.metrics import accuracy_score
from keras.metrics import AUC, F1Score, Precision, Accuracy

# Evaluate the model
predict = model1.predict([stft_test,mel_test,mfcc_test])
predicted_labels = label_binarizer.inverse_transform(predict).tolist()

# loss_eval, accuracy_eval = model.evaluate(X_eval, y_eval_one_hot)

# print(f'Evaluation Loss: {loss_eval}, Evaluation Accuracy: {accuracy_eval}')
# Calculate AUC ROC
auc_roc = AUC()
auc_roc.update_state(y_eval_one_hot, predict)
print("AUC ROC:", auc_roc.result().numpy())

# Calculate F1 Score
f1 = F1Score()
f1.update_state(y_eval_one_hot, predict)
print("F1 Score:", np.mean(f1.result().numpy()))

# Calculate Precision
pre = Precision()
pre.update_state(y_eval_one_hot, predict)
print("Precision Score", pre.result().numpy())

# Accuracy Score
acc = accuracy_score(labels_test, predicted_labels)
print("Accuracy Score", acc)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 465ms/step
# AUC ROC: 0.99470806
# F1 Score: 0.9334642
# Precision Score 0.9430894
# Accuracy Score 0.936

# %%
history = model1.fit([stft_train,  mel_train,mfcc_train], y_train_one_hot, batch_size=32, epochs=100, validation_data=([stft_val,mel_val,mfcc_val], y_val_one_hot),callbacks=[checkpoint1, early])
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2835 - loss: 1.8902
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_01_0.5000.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.2851 - loss: 1.8837 - val_accuracy: 0.5000 - val_loss: 1.2806
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5869 - loss: 1.0206
# Epoch 2: val_accuracy improved from 0.50000 to 0.67200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_02_0.6720.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5871 - loss: 1.0197 - val_accuracy: 0.6720 - val_loss: 0.8963
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6918 - loss: 0.8071
# Epoch 3: val_accuracy improved from 0.67200 to 0.69200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_03_0.6920.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.6923 - loss: 0.8064 - val_accuracy: 0.6920 - val_loss: 0.8058
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7467 - loss: 0.7038
# Epoch 4: val_accuracy improved from 0.69200 to 0.81600, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_04_0.8160.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.7470 - loss: 0.7028 - val_accuracy: 0.8160 - val_loss: 0.5676
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7954 - loss: 0.6011
# Epoch 5: val_accuracy improved from 0.81600 to 0.83600, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_05_0.8360.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.7956 - loss: 0.6004 - val_accuracy: 0.8360 - val_loss: 0.4962
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8249 - loss: 0.4801
# Epoch 6: val_accuracy improved from 0.83600 to 0.86400, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_06_0.8640.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8249 - loss: 0.4800 - val_accuracy: 0.8640 - val_loss: 0.4556
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8302 - loss: 0.4738
# Epoch 7: val_accuracy improved from 0.86400 to 0.89200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_07_0.8920.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8306 - loss: 0.4728 - val_accuracy: 0.8920 - val_loss: 0.3553
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9056 - loss: 0.3088
# Epoch 8: val_accuracy did not improve from 0.89200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9054 - loss: 0.3092 - val_accuracy: 0.8840 - val_loss: 0.3608
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8791 - loss: 0.3670
# Epoch 9: val_accuracy improved from 0.89200 to 0.93200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_09_0.9320.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8791 - loss: 0.3666 - val_accuracy: 0.9320 - val_loss: 0.2918
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8928 - loss: 0.2976
# Epoch 10: val_accuracy did not improve from 0.93200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8928 - loss: 0.2977 - val_accuracy: 0.8640 - val_loss: 0.3913
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9291 - loss: 0.2241
# Epoch 11: val_accuracy did not improve from 0.93200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9291 - loss: 0.2241 - val_accuracy: 0.9000 - val_loss: 0.2582
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9130 - loss: 0.2467
# Epoch 12: val_accuracy did not improve from 0.93200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9129 - loss: 0.2469 - val_accuracy: 0.9200 - val_loss: 0.2298
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.
val_accuracy did not improve from 0.96000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9491 - loss: 0.1385 - val_accuracy: 0.9480 - val_loss: 0.1742

# %%
from sklearn.metrics import accuracy_score
from keras.metrics import AUC, F1Score, Precision, Accuracy

# Evaluate the model
predict = model1.predict([stft_test,mel_test,mfcc_test])
predicted_labels = label_binarizer.inverse_transform(predict).tolist()

# loss_eval, accuracy_eval = model.evaluate(X_eval, y_eval_one_hot)

# print(f'Evaluation Loss: {loss_eval}, Evaluation Accuracy: {accuracy_eval}')
# Calculate AUC ROC
auc_roc = AUC()
auc_roc.update_state(y_eval_one_hot, predict)
print("AUC ROC:", auc_roc.result().numpy())

# Calculate F1 Score
f1 = F1Score()
f1.update_state(y_eval_one_hot, predict)
print("F1 Score:", np.mean(f1.result().numpy()))

# Calculate Precision
pre = Precision()
pre.update_state(y_eval_one_hot, predict)
print("Precision Score", pre.result().numpy())

# Accuracy Score
acc = accuracy_score(labels_test, predicted_labels)
print("Accuracy Score", acc)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 462ms/step
# AUC ROC: 0.997244
# F1 Score: 0.945145
# Precision Score 0.9518072
# Accuracy Score 0.948

# %%
history = model1.fit([stft_train,  mel_train,mfcc_train], y_train_one_hot, batch_size=32, epochs=100, validation_data=([stft_val,mel_val,mfcc_val], y_val_one_hot),callbacks=[checkpoint1, early])
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3280 - loss: 1.9578
# Epoch 1: val_accuracy improved from -inf to 0.49600, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_01_0.4960.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - accuracy: 0.3289 - loss: 1.9510 - val_accuracy: 0.4960 - val_loss: 1.2054
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5475 - loss: 1.0713
# Epoch 2: val_accuracy improved from 0.49600 to 0.50800, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_02_0.5080.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5481 - loss: 1.0700 - val_accuracy: 0.5080 - val_loss: 1.1198
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6697 - loss: 0.8452
# Epoch 3: val_accuracy improved from 0.50800 to 0.76800, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_03_0.7680.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.6700 - loss: 0.8446 - val_accuracy: 0.7680 - val_loss: 0.6904
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7949 - loss: 0.6056
# Epoch 4: val_accuracy improved from 0.76800 to 0.80400, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_04_0.8040.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.7951 - loss: 0.6050 - val_accuracy: 0.8040 - val_loss: 0.5423
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8247 - loss: 0.4989
# Epoch 5: val_accuracy did not improve from 0.80400
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.8250 - loss: 0.4982 - val_accuracy: 0.7600 - val_loss: 0.7440
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8334 - loss: 0.4991
# Epoch 6: val_accuracy improved from 0.80400 to 0.84800, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_06_0.8480.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8334 - loss: 0.4986 - val_accuracy: 0.8480 - val_loss: 0.4476
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8525 - loss: 0.4093
# Epoch 7: val_accuracy improved from 0.84800 to 0.87200, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_07_0.8720.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8527 - loss: 0.4088 - val_accuracy: 0.8720 - val_loss: 0.3249
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8883 - loss: 0.3114
# Epoch 8: val_accuracy did not improve from 0.87200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8881 - loss: 0.3121 - val_accuracy: 0.8200 - val_loss: 0.4889
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8673 - loss: 0.3583
# Epoch 9: val_accuracy did not improve from 0.87200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.8677 - loss: 0.3574 - val_accuracy: 0.8360 - val_loss: 0.4674
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8955 - loss: 0.3192
# Epoch 10: val_accuracy did not improve from 0.87200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.8953 - loss: 0.3196 - val_accuracy: 0.8160 - val_loss: 0.4453
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8824 - loss: 0.3291
# Epoch 11: val_accuracy improved from 0.87200 to 0.90000, saving model to D:\ProjectMusicGenre\data\checkpoint/latefusion/latefusion_11_0.9000.weights.h5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.8827 - loss: 0.3285 - val_accuracy: 0.9000 - val_loss: 0.2689
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.
val_accuracy did not improve from 0.96000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9699 - loss: 0.0896 - val_accuracy: 0.9400 - val_loss: 0.1720
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9715 - loss: 0.1000
# Epoch 32: val_accuracy did not improve from 0.96000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9715 - loss: 0.0999 - val_accuracy: 0.9240 - val_loss: 0.2107
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9793 - loss: 0.0716
# Epoch 33: val_accuracy did not improve from 0.96000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9792 - loss: 0.0717 - val_accuracy: 0.9600 - val_loss: 0.0842
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9820 - loss: 0.0565
# Epoch 34: val_accuracy did not improve from 0.96000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9819 - loss: 0.0571 - val_accuracy: 0.9520 - val_loss: 0.1158

# %%
from sklearn.metrics import accuracy_score
from keras.metrics import AUC, F1Score, Precision, Accuracy

# Evaluate the model
predict = model1.predict([stft_test,mel_test,mfcc_test])
predicted_labels = label_binarizer.inverse_transform(predict).tolist()

# loss_eval, accuracy_eval = model.evaluate(X_eval, y_eval_one_hot)

# print(f'Evaluation Loss: {loss_eval}, Evaluation Accuracy: {accuracy_eval}')
# Calculate AUC ROC
auc_roc = AUC()
auc_roc.update_state(y_eval_one_hot, predict)
print("AUC ROC:", auc_roc.result().numpy())

# Calculate F1 Score
f1 = F1Score()
f1.update_state(y_eval_one_hot, predict)
print("F1 Score:", np.mean(f1.result().numpy()))

# Calculate Precision
pre = Precision()
pre.update_state(y_eval_one_hot, predict)
print("Precision Score", pre.result().numpy())

# Accuracy Score
acc = accuracy_score(labels_test, predicted_labels)
print("Accuracy Score", acc)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 478ms/step
# AUC ROC: 0.99853593
# F1 Score: 0.9587166
# Precision Score 0.96385545
# Accuracy Score 0.96

# %%
for i in range(len(labels_test)):
    print(labels_test[i], predicted_labels[i])
# Out:
# cheo cheo
# hatxam hatxam
# cheo cheo
# hatxam hatxam
# cheo cheo
# catru catru
# cailuong cailuong
# catru catru
# cheo cheo
# catru catru
# catru catru
# cheo cheo
# hatxam hatxam
# cheo cheo
# cheo cheo
# cheo cheo
# cheo cheo
# chauvan chauvan
# cheo cheo
# cheo cheo
# hatxam hatxam
# cheo cheo
# chauvan chauvan
# cheo cheo
# cheo cheo
# catru catru
# cheo cheo
# chauvan chauvan
# cailuong cailuong
# cheo cheo
# cailuong cheo
# chauvan chauvan
# cheo cheo
# catru catru
# cheo cheo
# catru catru
# chauvan chauvan
# catru catru
# chauvan chauvan
# cailuong cailuong
# cheo cheo
# chauvan chauvan
# cailuong cailuong
# chauvan chauvan
# hatxam hatxam
# chauvan chauvan
# chauvan chauvan
# cailuong cailuong
# hatxam hatxam
# cheo cheo
# cheo cheo
# chauvan chauvan
# hatxam hatxam
# chauvan chauvan
# catru catru
# hatxam hatxam
# catru catru
# cailuong cheo
# catru catru
# hatxam hatxam
# hatxam hatxam
# catru catru
# hatxam hatxam
# hatxam hatxam
# cailuong cheo
# catru catru
# cheo cheo
# cheo cheo
# hatxam hatxam
# hatxam hatxam
# cheo cheo
# cheo cheo
# hatxam hatxam
# chauvan chauvan
# cailuong cailuong
# cailuong cailuong
# cheo cheo
# catru catru
# catru catru
# chauvan chauvan
# catru catru
